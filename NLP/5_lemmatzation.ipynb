# %%
import spacy

model = spacy.load("en_core_web_sm")

# %%
data = model("The children were running faster than the mice.")

# %%
for token in data:
    print(f"{token.text} -> {token.lemma_}")
# Out:
# The -> the
# children -> child
# were -> be
# running -> run
# faster -> fast
# than -> than
# the -> the
# mice -> mouse
# . -> .

# %%
for token in data:
    print(f"{token.vector}")
# Out:
# [ 0.4521444  -0.18112236 -0.48592037  0.79361576 -0.4218619  -0.77825546
#  -0.17254421  0.03689074 -0.55125886  0.03887425  0.23386768  0.8892697
#   0.66396785 -0.22872005 -0.6886084  -0.51650083 -0.21725799  1.9230644
#  -0.30192778 -0.6243358  -0.66056895 -0.17369959  0.5666706  -0.63549066
#   0.3829832  -0.16608088  0.6583697  -0.70830035 -0.28918785  1.4399773
#   0.9792837  -1.6245401  -0.39963472 -1.4935334  -0.39224067 -0.7420476
#  -0.7340579   0.32959306 -0.1658449   1.7845342   0.33448997  0.70730186
#  -0.6495052   0.4076251  -0.29005432 -0.02476338  0.5366183   1.14827
#   0.35429567  0.05326628  0.06773657  1.1191094   0.77734435  1.4178389
#   0.68839747 -0.06739008 -1.3265945   0.01827458 -1.4069971  -0.06706279
#  -0.30303872  0.58172554  0.05577792 -0.52486277  0.49087173 -0.72926617
#   0.57479984 -0.8416074  -0.51727486 -1.1687657  -0.09100625  0.70049196
#  -0.5770979  -0.31099686 -0.33419633 -0.7197303  -0.34495223 -0.91399306
# ...
